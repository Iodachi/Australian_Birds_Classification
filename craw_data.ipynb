# %%
import urllib.request, json
import sys
import os

#savePath="../data/xeno-canto-dataset-Australia-call/"
savePath="../data/xeno-canto-dataset-Australia-song/"

# %%
def save_json(searchTerms, birdName, country):
    numPages = 1
    page = 1
    # create a path to save json files and recordings
    path = savePath + birdName.replace(':', '') + "/" + country
    if not os.path.exists(path):
        print("Creating subdirectory " + path + " for downloaded files...")
        os.makedirs(path)
        # download a json file for every page found in a query
    while page < numPages + 1:
        print("Loading page " + str(page) + "...")
        url = 'https://www.xeno-canto.org/api/2/recordings?query={0}&page={1}'.format(searchTerms.replace(' ', '%20'),page)
        print(url)
        jsonPage = urllib.request.urlopen(url)
        jsondata = json.loads(jsonPage.read().decode('utf-8'))
        filename = path + "/jsondata_p" + str(page) + ".json"
        with open(filename, 'w') as outfile:
            json.dump(jsondata, outfile)
        # check number of pages
        numPages = jsondata['numPages']
        page = page + 1
    print("Found ", numPages, " pages in total.")
    # return number of files in json
    # each page contains 500 results, the last page can have less than 500 records
    print("Saved json for ", (numPages - 1) * 500 + len(jsondata['recordings']), " files")
    return path


# reads the json and return the list of values for selected json part
# i.e. "id" - ID number, "type": type of the bird sound such as call or song
# for all Xeno Canto files found with the given search terms.
def read_data(searchTerm, path):
    data = []
    numPages = 1
    page = 1
    # read all pages and save results in a list
    while page < numPages + 1:
        # read file
        with open(path + "/jsondata_p" + str(page) + ".json", 'r') as jsonfile:
            jsondata = jsonfile.read()
        jsondata = json.loads(jsondata)
        # check number of pages
        numPages = jsondata['numPages']
        # find "recordings" in a json and save a list with a search term
        for k in range(len(jsondata['recordings'])):
            data.append(jsondata["recordings"][k][searchTerm])
        page = page + 1
    return data


# downloads all sound files found with the search terms into xeno-canto directory
# into catalogue named after the search term (i.e. Apus apus)
# filename have two parts: the name of the bird in latin and ID number
def download(searchTerms, birdName, country):
    # create data/xeno-canto-dataset directory
    path = save_json(searchTerms, birdName, country)
    # get filenames: recording ID and bird name in latin from json
    filenamesID = read_data('id', path)
    filenamesCountry = read_data('cnt', path)
    # get website recording http download address from json
    fileaddress = read_data('file', path)
    numfiles = len(filenamesID)
    print("A total of ", numfiles, " files will be downloaded")
    for i in range(0, numfiles):
        print("Saving file ", i + 1, "/", numfiles,
              savePath + birdName.replace(':', '') + filenamesID[
                  i] + ".mp3")
        print(fileaddress[i], path + "/" + birdName + filenamesID[i] + ".mp3")
        
        urllib.request.urlretrieve(fileaddress[i], path + "/" + birdName + filenamesID[i] + ".mp3")

# %%
import ssl

ssl._create_default_https_context = ssl._create_unverified_context

#https://australian.museum/learn/animals/birds/birds-in-backyards-top-30-urban-birds/
AusBirds = [
            'Alisterus scapularis',
            'Gymnorhina tibicen',
            'Corvus coronoides',
            'Eudynamys orientalis',
            'Acridotheres tristis',
            'Ocyphaps lophotes',
            'Platycercus elegans',
            'Acanthorhynchus tenuirostris',
            'Eopsaltria australis',
            'Eolophus roseicapilla',
            'Cracticus torquatus',
            'Rhipidura albiscapa',
            'Passer domesticus',
            'Dacelo novaeguineae',
            'Anthochaera chrysoptera',
            'Grallina cyanoleuca',
            'Phylidonyris novaehollandiae',
            'Manorina melanocephala',
            'Strepera graculina',
            'Trichoglossus moluccanus','Trichoglossus ornatus','Trichoglossus flavoviridis','Trichoglossus chlorolepidotus', #*
            'Anthochaera carunculata',
            'Neochmia temporalis', 'Neochmia phaeton','Neochmia ruficauda', #**
            'Pycnonotus jocosus',
            'Zosterops lateralis',
            'Pardalotus punctatus', 'Pardalotus quadragintus', 'Pardalotus rubricatus', 'Pardalotus striatus', #**
            'Spilopelia chinensis',
            'Cacatua galerita',
            'Malurus cyaneus',
            'Rhipidura leucophrys',
            'Calyptorhynchus funereus'           
]
for bird in AusBirds:
    download(bird + ' type:call', bird.replace(' ', ''), 'countries')
    
for bird in AusBirds:
    download(bird + ' type:song', bird.replace(' ', ''), 'countries')
# Out:
# Creating subdirectory ../data/xeno-canto-dataset-Australia-song/Pardalotusquadragintus/countries for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Pardalotus%20quadragintus%20type:song&page=1
# Found  1  pages in total.
# Saved json for  0  files
# A total of  0  files will be downloaded
# Creating subdirectory ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus/countries for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Pardalotus%20rubricatus%20type:song&page=1
# Found  1  pages in total.
# Saved json for  12  files
# A total of  12  files will be downloaded
# Saving file  1 / 12 ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus641216.mp3
# https://xeno-canto.org/641216/download ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus/countries/Pardalotusrubricatus641216.mp3
# Saving file  2 / 12 ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus521834.mp3
# https://xeno-canto.org/521834/download ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus/countries/Pardalotusrubricatus521834.mp3
# Saving file  3 / 12 ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus434085.mp3
# https://xeno-canto.org/434085/download ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus/countries/Pardalotusrubricatus434085.mp3
# Saving file  4 / 12 ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus426344.mp3
# https://xeno-canto.org/426344/download ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus/countries/Pardalotusrubricatus426344.mp3
# Saving file  5 / 12 ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus334324.mp3
# https://xeno-canto.org/334324/download ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus/countries/Pardalotusrubricatus334324.mp3
# Saving file  6 / 12 ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus334323.mp3
# https://xeno-canto.org/334323/download ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus/countries/Pardalotusrubricatus334323.mp3
# Saving file  7 / 12 ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus287064.mp3
# https://xeno-canto.org/287064/download ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus/countries/Pardalotusrubricatus287064.mp3
# Saving file  8 / 12 ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus165212.mp3
# https://xeno-canto.org/165212/download ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus/countries/Pardalotusrubricatus165212.mp3
# Saving file  9 / 12 ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus165211.mp3
# https://xeno-canto.org/165211/download ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus/countries/Pardalotusrubricatus165211.mp3
# Saving file  10 / 12 ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus593535.mp3
# https://xeno-canto.org/593535/download ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus/countries/Pardalotusrubricatus593535.mp3
# Saving file  11 / 12 ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus327172.mp3
# https://xeno-canto.org/327172/download ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus/countries/Pardalotusrubricatus327172.mp3
# Saving file  12 / 12 ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus121416.mp3
# https://xeno-canto.org/121416/download ../data/xeno-canto-dataset-Australia-song/Pardalotusrubricatus/countries/Pardalotusrubricatus121416.mp3
# Creating subdirectory ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries for downloaded files...
# Loading page 1...
# https://www.xeno-canto.org/api/2/recordings?query=Pardalotus%20striatus%20type:song&page=1
# Found  1  pages in total.
# Saved json for  42  files
# A total of  42  files will be downloaded
# Saving file  1 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus673837.mp3
# https://xeno-canto.org/673837/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus673837.mp3
# Saving file  2 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus673836.mp3
# https://xeno-canto.org/673836/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus673836.mp3
# Saving file  3 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus673835.mp3
# https://xeno-canto.org/673835/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus673835.mp3
# Saving file  4 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus641523.mp3
# https://xeno-canto.org/641523/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus641523.mp3
# Saving file  5 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus628821.mp3
# https://xeno-canto.org/628821/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus628821.mp3
# Saving file  6 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus609295.mp3
# https://xeno-canto.org/609295/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus609295.mp3
# Saving file  7 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus609084.mp3
# https://xeno-canto.org/609084/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus609084.mp3
# Saving file  8 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus609045.mp3
# https://xeno-canto.org/609045/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus609045.mp3
# Saving file  9 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus608458.mp3
# https://xeno-canto.org/608458/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus608458.mp3
# Saving file  10 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus503540.mp3
# https://xeno-canto.org/503540/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus503540.mp3
# Saving file  11 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus501237.mp3
# https://xeno-canto.org/501237/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus501237.mp3
# Saving file  12 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus434752.mp3
# https://xeno-canto.org/434752/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus434752.mp3
# Saving file  13 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus434557.mp3
# https://xeno-canto.org/434557/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus434557.mp3
# Saving file  14 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus382721.mp3
# https://xeno-canto.org/382721/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus382721.mp3
# Saving file  15 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus334416.mp3
# https://xeno-canto.org/334416/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus334416.mp3
# Saving file  16 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus334415.mp3
# https://xeno-canto.org/334415/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus334415.mp3
# Saving file  17 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus284386.mp3
# https://xeno-canto.org/284386/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus284386.mp3
# Saving file  18 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus284385.mp3
# https://xeno-canto.org/284385/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus284385.mp3
# Saving file  19 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus200310.mp3
# https://xeno-canto.org/200310/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus200310.mp3
# Saving file  20 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus197585.mp3
# https://xeno-canto.org/197585/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus197585.mp3
# Saving file  21 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus197584.mp3
# https://xeno-canto.org/197584/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus197584.mp3
# Saving file  22 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus171818.mp3
# https://xeno-canto.org/171818/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus171818.mp3
# Saving file  23 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus86003.mp3
# https://xeno-canto.org/86003/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus86003.mp3
# Saving file  24 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus706584.mp3
# https://xeno-canto.org/706584/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus706584.mp3
# Saving file  25 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus562246.mp3
# https://xeno-canto.org/562246/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus562246.mp3
# Saving file  26 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus555134.mp3
# https://xeno-canto.org/555134/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus555134.mp3
# Saving file  27 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus481266.mp3
# https://xeno-canto.org/481266/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus481266.mp3
# Saving file  28 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus481264.mp3
# https://xeno-canto.org/481264/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus481264.mp3
# Saving file  29 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus478686.mp3
# https://xeno-canto.org/478686/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus478686.mp3
# Saving file  30 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus478684.mp3
# https://xeno-canto.org/478684/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus478684.mp3
# Saving file  31 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus477496.mp3
# https://xeno-canto.org/477496/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus477496.mp3
# Saving file  32 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus407996.mp3
# https://xeno-canto.org/407996/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus407996.mp3
# Saving file  33 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus407989.mp3
# https://xeno-canto.org/407989/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus407989.mp3
# Saving file  34 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus327851.mp3
# https://xeno-canto.org/327851/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus327851.mp3
# Saving file  35 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus265196.mp3
# https://xeno-canto.org/265196/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus265196.mp3
# Saving file  36 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus265173.mp3
# https://xeno-canto.org/265173/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus265173.mp3
# Saving file  37 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus156411.mp3
# https://xeno-canto.org/156411/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus156411.mp3
# Saving file  38 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus98473.mp3
# https://xeno-canto.org/98473/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus98473.mp3
# Saving file  39 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus68975.mp3
# https://xeno-canto.org/68975/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus68975.mp3
# Saving file  40 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus40683.mp3
# https://xeno-canto.org/40683/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus40683.mp3
# Saving file  41 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus165149.mp3
# https://xeno-canto.org/165149/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus165149.mp3
# Saving file  42 / 42 ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus36413.mp3
# https://xeno-canto.org/36413/download ../data/xeno-canto-dataset-Australia-song/Pardalotusstriatus/countries/Pardalotusstriatus36413.mp3
